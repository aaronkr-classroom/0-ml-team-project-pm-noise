# %%
import matplotlib.pyplot as plt

# 데이터 리스트
accuracy = [0.8290, 0.9496, 0.9645, 0.9718, 0.9748, 0.9779, 0.9801, 0.9809, 0.9806, 0.9819]
val_accuracy = [0.9590, 0.9779, 0.9799, 0.9830, 0.9859, 0.9885, 0.9899, 0.9899, 0.9906, 0.9900]
loss = [0.4645, 0.1577, 0.1128, 0.0899, 0.0788, 0.0700, 0.0638, 0.0601, 0.0582, 0.0538]
val_loss = [0.1341, 0.0738, 0.0594, 0.0514, 0.0420, 0.0364, 0.0330, 0.0319, 0.0302, 0.0287]

# 학습 및 검증 정확도 그래프
plt.plot(accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("1_accuracy.png")
plt.show()

# 학습 및 검증 손실 그래프
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig("2_loss.png")
plt.show()
